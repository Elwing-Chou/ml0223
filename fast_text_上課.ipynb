# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/ml0223/blob/main/fast_text_%E4%B8%8A%E8%AA%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 下載fasttext千錘百鍊預訓練好的詞向量
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.zh.300.bin.gz
# !gunzip cc.zh.300.bin.gz
# Out:
# --2021-04-15 05:50:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.zh.300.bin.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4478681770 (4.2G) [application/octet-stream]
# Saving to: ‘cc.zh.300.bin.gz’
#
# cc.zh.300.bin.gz    100%[===================>]   4.17G  28.6MB/s    in 2m 29s
#
# 2021-04-15 05:52:39 (28.7 MB/s) - ‘cc.zh.300.bin.gz’ saved [4478681770/4478681770]
#
# gzip: cc.en.300.bin.gz: No such file or directory

# %%
from gensim.models.fasttext import FastText
model = FastText.load_fasttext_format('cc.zh.300.bin')

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# 我們的模型裡面有多少個詞
len(model.wv.vocab)
# Out:
# 2000000

# %%
model.wv["分鐘"]
# Out:
# array([-1.20621361e-02, -3.78011078e-01,  6.35303140e-01,  6.14471316e-01,
#         6.48206621e-02, -1.10318676e-01, -1.78651854e-01,  1.76284075e-01,
#         4.36085105e-01,  3.53268161e-02,  5.12982681e-02, -7.96686951e-03,
#        -4.43906561e-02,  2.66018733e-02, -5.79598323e-02, -1.57749221e-01,
#         4.74500954e-02,  2.65078247e-01, -9.79633778e-02,  4.61232811e-02,
#         1.36461724e-02, -4.96780761e-02,  2.49421105e-01,  1.04983576e-01,
#        -6.98071942e-02,  1.02498814e-01,  1.72967225e-01,  2.31298566e-01,
#         2.56588012e-02,  2.61356700e-02,  2.95880456e-02,  1.88339844e-01,
#        -5.33969887e-02,  1.76568516e-02,  1.99295908e-01, -1.04015745e-01,
#         1.61246121e-01, -7.90254697e-02,  2.37817839e-01, -4.25717831e-02,
#        -4.57396172e-02,  1.59455240e-01, -1.00915777e-02, -1.89261675e-01,
#        -1.47231668e-01,  8.01619217e-02, -3.53082299e-01, -3.34392488e-03,
# ...

# %%
word = "\u4E94\u6708\u5929"#@param {type:"string"}
print(word, "長這樣:")
model.wv[word]
# Out:
# 五月天 長這樣:
# array([ 2.82819308e-02,  4.29533683e-02,  9.57840234e-02,  1.38049424e-01,
#        -1.23814888e-01, -7.41634816e-02,  6.43098876e-02,  3.09208408e-04,
#         1.15740076e-01, -1.76323757e-01, -9.26368684e-02, -6.69668289e-03,
#         1.98636532e-01,  2.39945613e-02, -2.62314677e-01,  1.14349797e-01,
#        -3.48311886e-02,  8.03926736e-02,  9.96904522e-02, -2.35699695e-02,
#         2.35910788e-01,  5.05090132e-02, -2.75493897e-02, -8.59001130e-02,
#        -6.35966733e-02, -8.81980211e-02, -8.46317485e-02,  3.16980965e-02,
#        -1.84736505e-01,  1.72797088e-02,  1.39268674e-03,  1.28517643e-01,
#         7.57264160e-03, -5.77820316e-02, -1.35732353e-01,  9.72952917e-02,
#        -1.01045243e-01, -7.21212924e-02, -1.67097747e-02, -4.91435863e-02,
#         5.64303808e-02, -9.19092223e-02,  7.48488531e-02, -6.98813573e-02,
#        -4.39888686e-02,  1.16728008e-01,  2.21804336e-01, -5.10228463e-02,
# ...

# %%
#@title 找出相似詞!!!

text = '\u92FC\u9435\u4EBA' #@param {type:"string"}
model.wv.most_similar(text)
# Out:
# [('美國隊長', 0.6064475178718567),
#  ('雷神索爾', 0.586412787437439),
#  ('無敵浩克', 0.5794855952262878),
#  ('鋼鐵', 0.5722165107727051),
#  ('美國隊長3', 0.567979097366333),
#  ('鋼鐵俠', 0.5544332265853882),
#  ('美隊', 0.5441727638244629),
#  ('鋼鐵俠3', 0.5431514978408813),
#  ('變形金剛', 0.5403496623039246),
#  ('竊盜城', 0.5377448797225952)]

# %%
"轉蛋" in model.wv.vocab
# Out:
# True

# %%
#@title 比較兩個特定詞的相似度

text1 = '\u8AB2\u91D1' #@param {type:"string"}
text2 = '\u8F49\u86CB' #@param {type:"string"}
model.wv.similarity(text1, text2)
# Out:
# 0.52832663

# %%
#@title 找到不是同一掛的詞

text1 = '\u5468\u6770\u502B' #@param {type:"string"}
text2 = '\u856D\u656C\u9A30' #@param {type:"string"}
text3 = '\u76E7\u5EE3\u4EF2' #@param {type:"string"}
text4 = '\u8521\u4F9D\u6797' #@param {type:"string"}

notmatch = model.wv.doesnt_match([text1, text2, text3, text4])
print("不是同一掛的:", notmatch)
# Out:
# 不是同一掛的: 蔡依林

# %%
#@title 給電腦做智力測驗(詞1 - 詞3 = ? - 詞2)

# text1 + text2 - text3 = ?
# text1 - text3 = ? - text2
text1 = '\u665A\u4E0A' #@param {type:"string"}
text2 = '\u6625\u5929' #@param {type:"string"}
text3 = '\u767D\u5929' #@param {type:"string"}
question = model.wv.most_similar(positive=[text1, text2], negative=[text3])
print(text1, "-", text3, "=", "?", "-", text2)
question
# Out:
# 晚上 - 白天 = ? - 春天
# [('秋天', 0.6770060062408447),
#  ('初春', 0.5704118013381958),
#  ('夏天', 0.5670797824859619),
#  ('冬天', 0.5597495436668396),
#  ('初夏', 0.5520045757293701),
#  ('深秋', 0.5471979379653931),
#  ('张小五', 0.5340253114700317),
#  ('那年', 0.5214204788208008),
#  ('三月', 0.5209508538246155),
#  ('李春天', 0.5175076723098755)]

# %%
text1 = '\u665A\u4E0A' #@param {type:"string"}
text3 = '\u767D\u5929' #@param {type:"string"}
question = model.wv.most_similar(positive=[text1], negative=[text3])
question
# Out:
# [('三時許', 0.37563636898994446),
#  ('號晚', 0.3698442578315735),
#  ('時許', 0.3677302598953247),
#  ('下午', 0.36458393931388855),
#  ('早上', 0.3531913459300995),
#  ('參加完', 0.35159045457839966),
#  ('12点40', 0.35059744119644165),
#  ('事源', 0.3504692614078522),
#  ('當晚', 0.3492421507835388),
#  ('9点30分', 0.34670019149780273)]

# %%
text = "福原愛"
print("machine-washabled有在字典裡?", text in model.wv.vocab)
model.wv.most_similar(text)
# Out:
# machine-washabled有在字典裡? True
# [('江宏傑', 0.7769640684127808),
#  ('江宏杰', 0.6791825294494629),
#  ('王明俊', 0.6453269124031067),
#  ('李亞軒', 0.6328298449516296),
#  ('鄭怡靜', 0.6137341260910034),
#  ('莊智淵', 0.6112247705459595),
#  ('陳建安', 0.6087343692779541),
#  ('海碩盃', 0.6062625646591187),
#  ('松平健太', 0.6059966087341309),
#  ('福原爱', 0.6043314933776855)]
